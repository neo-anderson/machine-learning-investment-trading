# 2000-12-28      5520800
# 2000-12-29      4970400
# 2001-01-02     10606000
# 2001-01-03     12469600
# 2001-01-04     14770600
# 2001-01-05      7960200
# 2001-01-08      9529200
# 2001-01-09      8516200
# 2001-01-10      7963200
# 2001-01-11      6909000
# 2001-01-12      7212000
# 2001-01-16      7163600
# 2001-01-17      7651800
# 2001-01-18      7014400
# 2001-01-19      9824200
# 2001-01-22      6874600
# 2001-01-23      7707800
# 2001-01-24      9189400
# 2001-01-25      7486800
# ...                 ...
# 2014-11-11      8519256
# 2014-11-12     12767870
# 2014-11-13     12006900
# 2014-11-14     10939420
# 2014-11-17     10647040
# 2014-11-18     26132605
# 2014-11-19     25347462
# 2014-11-20     13462838
# 2014-11-21     14382570
# 2014-11-24     12844590
# 2014-11-25     10728465
# 2014-11-26      9196101
# 2014-11-28     10501972
# 2014-12-01     10052497
# 2014-12-02      9860626
# 2014-12-04     13775398
# 2014-12-05     12525974
# 2014-12-09     25455917
# 2014-12-10     18234879
# 2014-12-11     16168066
# 2014-12-15     23235600
# 2014-12-16     23417350
# 2014-12-17     20175592
# 2014-12-18     17918113
# 2014-12-19     23926178
# 2014-12-22     11131276
# 2014-12-23     13026464
# 2014-12-24      6405910
# 2014-12-26      6365767
# 2014-12-30      9160093
#
# [3528 rows x 12 columns]

# %%
data.shape
# Out:
# (3528, 12)

# %%
path = "intraQuarter/"
def stock_prices():
    df = pd.DataFrame()
    statspath = path+'_KeyStats'
    stock_list = [x[0] for x in os.walk(statspath)]
    for each_dir in stock_list[1:]:
        try:
            ticker = each_dir.split("/")[2]
            print(ticker)
            name = "WIKI/"+ticker.upper()
            data = Quandl.get(name,
                              trim_start = "2000-12-12",
                              trim_end = "2014-12-30",
                              authtoken=auth_tok)
            data[ticker.upper()] = data["Adj. Close"]
            df = pd.concat([df, data[ticker.upper()]], axis = 1)
        except Exception as e:
            print(name,str(e))
            time.sleep(10)
    print(df.head())
    df.to_csv('stock_prices.csv')
stock_prices()
# Out:
# a
# aa
# aapl
# abbv
# abc
# abt
# ace
# aci
# acn
# act
# adbe
# adi
# adm
# adp
# adsk
# adt
# aee
# aeo
# aep
# aes
# aet
# afl
# agn
# aig
# aiv
# aiz
# akam
# all
# altr
# alxn
# amat
# amd
# amgn
# amp
# amt
# amzn
# an
# anf
# ann
# aon
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-14c85ee8f0e1> in <module>()
#      20     print(df.head())
#      21     df.to_csv('stock_prices.csv')
# ---> 22 stock_prices()
#
# <ipython-input-18-14c85ee8f0e1> in stock_prices()
#      12                               trim_start = "2000-12-12",
#      13                               trim_end = "2014-12-30",
# ---> 14                               authtoken=auth_tok)
#      15             data[ticker.upper()] = data["Adj. Close"]
#      16             df = pd.concat([df, data[ticker.upper()]], axis = 1)
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/site-packages/Quandl/Quandl.py in get(dataset, **kwargs)
#     117         return url      # for test purpose
#     118     try:
# --> 119         urldata = _download(url)
#     120         if verbose and verbose != 'no':
#     121             print("Returning Dataframe for ", dataset)
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/site-packages/Quandl/Quandl.py in _download(url)
#     312 # Download data into pandas dataframe
#     313 def _download(url):
# --> 314     dframe = pd.read_csv(url, index_col=0, parse_dates=True)
#     315     return dframe
#     316
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     450                     infer_datetime_format=infer_datetime_format)
#     451
# --> 452         return _read(filepath_or_buffer, kwds)
#     453
#     454     parser_f.__name__ = name
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     220
#     221     filepath_or_buffer, _ = get_filepath_or_buffer(filepath_or_buffer,
# --> 222                                                    encoding)
#     223
#     224     if kwds.get('date_parser', None) is not None:
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding)
#     116
#     117     if _is_url(filepath_or_buffer):
# --> 118         req = _urlopen(str(filepath_or_buffer))
#     119         return maybe_read_encoded_stream(req, encoding)
#     120
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     159     else:
#     160         opener = _opener
# --> 161     return opener.open(url, data, timeout)
#     162
#     163 def install_opener(opener):
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/urllib/request.py in open(self, fullurl, data, timeout)
#     461             req = meth(req)
#     462
# --> 463         response = self._open(req, data)
#     464
#     465         # post-process response
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/urllib/request.py in _open(self, req, data)
#     479         protocol = req.type
#     480         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 481                                   '_open', req)
#     482         if result:
#     483             return result
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     439         for handler in handlers:
#     440             func = getattr(handler, meth_name)
# --> 441             result = func(*args)
#     442             if result is not None:
#     443                 return result
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/urllib/request.py in https_open(self, req)
#    1223         def https_open(self, req):
#    1224             return self.do_open(http.client.HTTPSConnection, req,
# -> 1225                 context=self._context, check_hostname=self._check_hostname)
#    1226
#    1227         https_request = AbstractHTTPHandler.do_request_
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1183             except OSError as err: # timeout error
#    1184                 raise URLError(err)
# -> 1185             r = h.getresponse()
#    1186         except:
#    1187             h.close()
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/http/client.py in getresponse(self)
#    1169
#    1170         try:
# -> 1171             response.begin()
#    1172             assert response.will_close != _UNKNOWN
#    1173             self.__state = _CS_IDLE
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/http/client.py in begin(self)
#     349         # read until we get a non-100 response
#     350         while True:
# --> 351             version, status, reason = self._read_status()
#     352             if status != CONTINUE:
#     353                 break
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/http/client.py in _read_status(self)
#     311
#     312     def _read_status(self):
# --> 313         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     314         if len(line) > _MAXLINE:
#     315             raise LineTooLong("status line")
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/socket.py in readinto(self, b)
#     372         while True:
#     373             try:
# --> 374                 return self._sock.recv_into(b)
#     375             except timeout:
#     376                 self._timeout_occurred = True
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/ssl.py in recv_into(self, buffer, nbytes, flags)
#     749                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     750                   self.__class__)
# --> 751             return self.read(nbytes, buffer)
#     752         else:
#     753             return socket.recv_into(self, buffer, nbytes, flags)
#
# /Users/aswinrajkumar/anaconda/lib/python3.4/ssl.py in read(self, len, buffer)
#     621         try:
#     622             if buffer is not None:
# --> 623                 v = self._sslobj.read(len, buffer)
#     624             else:
#     625                 v = self._sslobj.read(len or 1024)
#
# KeyboardInterrupt:
